# %%
import json
import numpy as np
from matplotlib import pyplot as plt

# %%
f = open('.asv/results/hydra/c701627d-virtualenv-py3.8-pennylane-tensorflow-torch.json')

# %%
data = json.load(f)

# %%
f.close()

# %%
data.keys()
# Out:
# dict_keys(['results', 'params', 'requirements', 'commit_hash', 'date', 'env_name', 'python', 'profiles', 'started_at', 'ended_at', 'benchmark_version', 'version'])

# %%
data['results']['asv.scaling.CircuitEvaluation_scaling.time_circuit'].keys()
# Out:
# dict_keys(['result', 'stats', 'params'])

# %%
data['results']['asv.scaling.CircuitEvaluation_scaling.time_circuit']['params']
# Out:
# [['1', '2', '3', '4', '5', '7', '9', '11'],
#  ['1', '2', '3', '4', '5', '6', '8', '10']]

# %%
len(data['results']['asv.scaling.CircuitEvaluation_scaling.time_circuit']['result'])
# Out:
# 64

# %%
times = np.reshape(np.array(data['results']['asv.scaling.CircuitEvaluation_scaling.time_circuit']['result']), (8,8))

# %%
times[0]
# Out:
# array([0.0031223 , 0.00353897, 0.00402305, 0.00454935, 0.00503145,
#        0.00543127, 0.00628452, 0.0077463 ])

# %%
for row in times:
    plt.plot(row)
    
plt.show()

# %%
plt.plot(times[0])
